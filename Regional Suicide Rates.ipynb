# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mw_data = "Resources/midwest.csv"
s_data = "Resources/south.csv"
ne_data = "Resources/northeast.csv"
w_data = "Resources/west.csv"

# %%
# Read data and store into a data frame for sex
midwest_suicide_df = pd.read_csv(mw_data)
south_suicide_df = pd.read_csv(s_data)
northeast_suicide_df = pd.read_csv(ne_data)
west_suicide_df = pd.read_csv(w_data)
west_suicide_df.head()
# Out:
#   Region  Year  Deaths  Population  Crude Rate
# 0   West  2013   10493    74230053       14.14
# 1   West  2014   11085    74999361       14.78
# 2   West  2015   11313    75822786       14.92
# 3   West  2016   11516    76644950       15.03
# 4   West  2017   12010    77410622       15.51

# %%
mw_rate = midwest_suicide_df["Crude Rate"]
w_rate = west_suicide_df["Crude Rate"]
s_rate = south_suicide_df["Crude Rate"]
ne_rate = northeast_suicide_df["Crude Rate"]

x = np.arange(5)
years = "2013", "2014", "2015", "2016", "2017"

plt.plot(years, mw_rate, color="indianred", marker="o", label="Midwest")
plt.plot(years, w_rate, color="darkseagreen", marker="o", label="West")
plt.plot(years, ne_rate, color="cornflowerblue", marker="o", label="Northeast")
plt.plot(years, s_rate, color="goldenrod", marker="o", label="South")
plt.title("Regional Suicide Rates Per Capita (2013 - 2017)", fontsize = 15)
plt.xlabel("Year")
plt.ylabel("Suicides Per Capita (%)")
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, p: '{}%'.format(int(x))))
plt.legend(loc="best")
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# mw_rate = midwest_suicide_df["Crude Rate"]
# w_rate = west_suicide_df["Crude Rate"]
# s_rate = south_suicide_df["Crude Rate"]
# ne_rate = northeast_suicide_df["Crude Rate"]

# x = np.arange(5)
# years = "2013", "2014", "2015", "2016", "2017"
# width = 0.8


# plt.bar(x + .3, w_rate, color="green", width = 0.2, label = "West")
# plt.bar(x + .1, s_rate, color="red", width = 0.2, label = "South")
# plt.bar(x - .1, mw_rate, color="blue", width = 0.2, label = "Midwest")
# plt.bar(x - .3, ne_rate, color="yellow", width = 0.2, label = "Northeast")

# tick_locations = [value for value in years]
# plt.xticks(x, years)
# plt.xlim = (-10, len(years)+.25)
# plt.ylim = (0, max(w_rate)+100)

# plt.title("Regional Suicide Rates (2013 - 2017)", fontsize = 16)
# plt.xlabel("Year")
# plt.ylabel("Percent of Suicide Deaths (Regional)")
# plt.legend(loc=(1.05, 0.4))
# plt.tight_layout()

# plt.show()
